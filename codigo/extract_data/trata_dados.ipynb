# %%
import os
import re
import shutil
from rapidfuzz import fuzz # Faster than fuzzywuzzy
import numpy as np
import pandas as pd

# %%
df_principal = pd.read_excel("C:/luis/Iso_olhos/dados/Pacientes_Torica.xlsx", header=3, engine= "openpyxl", usecols=range(21))

df_principal.rename(columns=str.lower, inplace=True)

# %%
def _extract_filename_components(filename: str) -> tuple[list[str], list[str]]:
    """
    Extract alphabetic and numeric groups from the name of a given file

    Parameters:
        filename: name of the file

    Returns:
        alphabetic_parts: list of strings with the alphabetic components from filename
        numeric_parts: list of the numeric parts from filename
    """

    filename = filename.lower()
    alphabetic_parts = re.findall(r'[^\W\d_]+', filename) # Extract alphabetic parts from filenames in directory
    numeric_parts = re.findall(r'[\d]+', filename) # Extract Number patters from filenames

    return alphabetic_parts, numeric_parts

def matches_number(search_number: str, numeric_parts:list[str]) -> bool:
    """
    Check if seach_number appears in numeric_parts list
    """
    return search_number in numeric_parts

def matches_name(name_parts: list[str], alphabetic_parts: list[str], similarity_threshold: int) -> bool:
    """
    Check if the similarity between the search_name list and the alphabetic_parts list is greater than the similarity_threshold
    """
    name_parts = " ".join(name_parts)
    alphabetic_parts = " ".join(alphabetic_parts)
    similarity_score = fuzz.token_sort_ratio(alphabetic_parts, name_parts)
    return similarity_score >= similarity_threshold

def find_matching_files(
    search_name: str, 
    search_number: str, 
    directory: str, 
    similarity_threshold: int = 80
    ) -> list[str]:
    """
    Find files in directory with names are similar to search_name using fuzzy functions or with numbers are equals to search_number

    Parameters:
        search_name (str): Name pattern to search for 
        search_number (str): Patient number to search in directory
        directory (str): Directory path to search in 
        similarity_threshold (int): Minimun similarity score (0-100) 

        (see: https://rapidfuzz.github.io/RapidFuzz/Usage/fuzz.html)

    Returns:
        list: Matching filenames (empty if none found)

    """
    name_parts = search_name.lower().split()
    matching_files = []

    for _, _, files in os.walk(directory):
        for filename in files:
            
            alphabetic_parts, numeric_parts = _extract_filename_components(filename) # Extract names and numbers patterns 


            # Try to find correspondent files with patient number
            if matches_number(search_number, numeric_parts):
                matching_files.append(filename)
                continue


            # Try to find correspondent files with patient name
            if matches_name(name_parts, alphabetic_parts, similarity_threshold):
                matching_files.append(filename)
        
    return matching_files

# %%
def _patient_number_on_name(patient_number, patient_filename) -> bool:
   """
   Check if patient name has the patient number in its beginning
   """
   filename_parts = patient_filename.split("_")

   if filename_parts:
      return patient_number == filename_parts[0]
   
   return False


def rename_files(files: list[str], number: int, directory: str) -> list[str]:
   """
   Take a list of files, add the number on the name of each file and return a list with the new name of each files

   Parameters:
      files: a list with the filenames
      number: the patient number wich will be add in the beginning of file
      directory: the directory of file
   """
   new_filenames = []
   for filename in files:

      # Check if the number are alredy in the beginning of filename
      if _patient_number_on_name(number, filename):
         new_filenames.append(filename)
         continue

      original_path = os.path.join(directory, filename)

      new_filename = f"{number}_{filename}"
      final_path = os.path.join(directory,new_filename)

      os.rename(original_path, final_path)

      new_filenames.append(new_filename)
   
   return new_filenames

def move_files(files: list[str], original_directory, final_directory) -> None:
   """
   Move each file of the files list from original_directory to final_directory
   """
   for filename in files:
      original_path = os.path.join(original_directory, filename)

      print(original_path)
      shutil.move(original_path, final_directory)

# %%
# acha os exames de cada paciente e separa em uma pasta

data_original_directory = "C:/luis/Iso_olhos/dados/Biometrias"
data_final_directory = "C:/luis/Iso_olhos/dados/Biometrias_identificadas"


for _,patient in df_principal.iterrows():
    patient_name = patient['nome']
    patient_number = str(patient['pront'])

    corresponding_files = find_matching_files(patient_name, patient_number, data_original_directory)

    
    if corresponding_files :
        print(corresponding_files)
        corresponding_files = rename_files(corresponding_files, patient_number, data_original_directory)

        move_files(corresponding_files, data_original_directory, data_final_directory)
# Out:
# ['ADEMIR MARTINS_PEIXOTO_121476_DOB19500530_AstigPlan_20241017094821.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\121476_ADEMIR MARTINS_PEIXOTO_121476_DOB19500530_AstigPlan_20241017094821.pdf
# ['114679_Adriana_Dias_da_Cunha_Oliveira_1968-01-16_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\114679_Adriana_Dias_da_Cunha_Oliveira_1968-01-16_IOL.pdf
# ['71580_Aguiar_Alaide_Pereira_Lima_1946-04-16_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\71580_Aguiar_Alaide_Pereira_Lima_1946-04-16_IOL.pdf
# ['109458_JREGE,_ALEXSANDRA_RIBEIRO_1971-04-30_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\109458_JREGE,_ALEXSANDRA_RIBEIRO_1971-04-30_IOL.pdf
# ['118023_ALIPIA_TEREZINHA_PEREIRA_BARBOSA_1945-02-27_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\118023_ALIPIA_TEREZINHA_PEREIRA_BARBOSA_1945-02-27_IOL.pdf
# ['PERRONI_ALIZETE RODRIGUES_105701_DOB19590725_AstigPlan_20240925141738.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\105701_PERRONI_ALIZETE RODRIGUES_105701_DOB19590725_AstigPlan_20240925141738.pdf
# ['110821_Temer_Ana_Carolina_Rocha_Pessoa_1958-02-24_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\110821_Temer_Ana_Carolina_Rocha_Pessoa_1958-02-24_IOL.pdf
# ['ANA LUCIA_SILVA_48439_DOB19720425_AstigPlan_20240918163940.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\48439_ANA LUCIA_SILVA_48439_DOB19720425_AstigPlan_20240918163940.pdf
# ['30833_Avila_Angelina_Maria_Conceicao_1939-04-25_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\30833_Avila_Angelina_Maria_Conceicao_1939-04-25_IOL.pdf
# ['35060_ANIR_FERREIRA_ALMEIDA_1953-07-17_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\35060_ANIR_FERREIRA_ALMEIDA_1953-07-17_IOL.pdf
# ['MACCHERONI_ANSELMO CUNHA_34912_DOB19581216_AstigPlan_20240903142755.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\34912_MACCHERONI_ANSELMO CUNHA_34912_DOB19581216_AstigPlan_20240903142755.pdf
# ['ANTONIO DONIZETE GREGORIO_LIMA_5178_DOB19620613_AstigPlan_20241008161252.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\5178_ANTONIO DONIZETE GREGORIO_LIMA_5178_DOB19620613_AstigPlan_20241008161252.pdf
# ['110440_Oliveira_Belchior_Santana,_1960-02-02_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\110440_Oliveira_Belchior_Santana,_1960-02-02_IOL.pdf
# ['23051_MELO_BENILDO_1948-06-22_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias
IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\5076_Junior,_Jose_Canesi_1944-03-29_IOL.pdf
# ['3685_MORAES_VERA_LUCIA_S_1966-12-09_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\3685_MORAES_VERA_LUCIA_S_1966-12-09_IOL.pdf
# ['105010_CANTARIM_HELOISA_ALVES_BORGES_1964-05-18_IOL.pdf']
# C:/luis/Iso_olhos/dados/Biometrias\105010_CANTARIM_HELOISA_ALVES_BORGES_1964-05-18_IOL.pdf

# %%
# Adiciona uma coluna  para dizer se o paciente tem exame identificado ou não


df_principal['tem_exame'] = df_principal.apply(
    lambda patient : bool(find_matching_files(patient['nome'], str(patient['pront']), data_final_directory)),
    axis = 1 # Apply to each row
)

# %%
df_principal.head()
# Out:
#     pront                        nome       sexo olho operado     k1  \
# 0  121476      ADEMIR MARTINS PEIXOTO  Masculino      Direito  42.92
# 1  114679       ADRIANA DIAS DA CUNHA   Feminino      Direito  40.67
# 2   71580  ALAIDE PEREIRA LIMA AGUIAR   Feminino      Direito  44.59
# 3   65154    ALAOR DE OLIVEIRA PINHAL  Masculino      Direito    NaN
# 4   65154    ALAOR DE OLIVEIRA PINHAL  Masculino     Esquerdo    NaN
#
#    eixo plano     k2  eixo curvo     al   acd  ... refração pré operatória  \
# 0        92.0  46.72         2.0  22.67  2.98  ...       +3,00  -4,00  95º
# 1         3.0  42.75        93.0  24.57  2.94  ...       +0,50  -1,00 170º
# 2       106.0  45.62        16.0  23.59  3.53  ...        +1,75 -1,00 100º
# 3         NaN    NaN         NaN    NaN   NaN  ...        +1,00 -2,00 100º
# 4         NaN    NaN         NaN    NaN   NaN  ...        +1,75  -1,75 70º
#
#   astig refracional pré op astig anterior topo pré op  \
# 0                    -4.00                        2.6
# 1                    -1.00                        0.8
# 2                    -1.00                        0.9
# 3                    -2.00                        0.8
# 4                    -1.75                        1.0
#
#    astig posterior topo pré  lente indicada  lente implantada   \
# 0                       0.1        T9 +23.0      T8 +23,5 a 2°
# 1                       0.4        T3 +20,0    T3 +21,50 a 80°
# 2                       0.1       T4 +19,50     T4 +19,50 a 5°
# 3                       0.1             NaN   T5 +22,50 a 160°
# 4                       0.0             NaN    T5 +22,0 a 180°
#
#   refração pós operatória astig refracional pós op   \
# 0                  plano                       0.00
# 1                     0.5                      0.00
# 2        +1,00 -0,50 125º                     -0.50
# 3       plano -0,75  150º                     -0.75
# 4                   plano                      0.00
#
#           classificação astigmatismo   tem_exame
# 0  Regular assimétrico contra a regra       True
# 1  Regular simétrico a favor da regra       True
# 2    Regular simétrico contra a regra       True
# 3  Regular assimétrico contra a regra      False
# 4   Regular simetrico contra a regra       False
#
# [5 rows x 22 columns]

# %%
df_sem_exame = df_principal[df_principal['tem_exame'] == False]
print(df_sem_exame.sort_values(by='pront'))
# Out:
#       pront                                  nome       sexo olho operado  k1  \
# 98     7898              MARIA APARECIDA DE SOUZA   Feminino     Esquerdo NaN
# 51     8005             ELIANE GUIMARAES FERREIRA   Feminino      Direito NaN
# 243   86347              JEFFERSON MANOEL CARDOSO  Masculino      Direito NaN
# 244   86347              JEFFERSON MANOEL CARDOSO  Masculino     Esquerdo NaN
# 238   87735                          TAMICO YOKOO   Feminino      Direito NaN
# 239   87735                          TAMICO YOKOO   Feminino     Esquerdo NaN
# 43    99003                       DIVINO DE SOUZA  Masculino     Esquerdo NaN
# 42    99003                       DIVINO DE SOUZA  Masculino      Direito NaN
# 165  107772         VERA LUCIA DE JESUS TRIGUEIRO   Feminino      Direito NaN
# 166  107772         VERA LUCIA DE JESUS TRIGUEIRO   Feminino     Esquerdo NaN
# 155  107791             TERESA RESENDE DOS SANTOS   Feminino      Direito NaN
# 68   108117                     HOMERO PENA BORJA  Masculino     Esquerdo NaN
# 67   108117                     HOMERO PENA BORJA  Masculino      Direito NaN
# 92   110760      MARCIA ROGELIA NASCIMENTO MORAES   Feminino      Direito NaN
# 30   110982                CLAUCYMAR GUERRA ROCHA   Feminino      Direito NaN
# 97   117107        MARIA ANGELA BENEDETTI DELAIBA   Feminino      Direito NaN
# 124  117517                    MEIRE LUCE RESENDE   Feminino     Esquerdo NaN
# 123  117517                    MEIRE LUCE RESENDE   Feminino      Direito NaN
# 118  119012           MARLENE RODRIGUES PRUDENTE    Feminino      Direito NaN
# 122  120362               MAURO DOS SANTOS JUNIOR  Masculino     Esquerdo NaN
#
#      eixo plano  k2  eixo curvo  al  acd  ...   refração pré operatória  \
# 98          NaN NaN         NaN NaN  NaN  ...    -8,00    -2,00     90°
# 51          NaN NaN         NaN NaN  NaN  ...            3,5  -0,50  95
# 240         NaN NaN         NaN NaN  NaN  ...         -7,00 -3,00 a 10°
# 255         NaN NaN         NaN NaN  NaN  ...         -5,50 -1,00 a 15°
# 256         NaN NaN         NaN NaN  NaN  ...        -5,50 -1,50 a 165°
# 253         NaN NaN         NaN NaN  NaN  ...        -1,25 -1,75 a 170°
# 254         NaN NaN         NaN NaN  NaN  ...       -1,75 - 1,25 a 180°
# 247         NaN NaN         NaN NaN  NaN  ...          -1,25-1,50 a 90°
# 248         NaN NaN         NaN NaN  NaN  ...          0,25 -1,25 a 85°
# 261         NaN NaN         NaN NaN  NaN  ...          0,75 -2,25 a 80°
# 260         NaN NaN         NaN NaN  NaN  ...         3,50 -1,00 a 110°
# 259         NaN NaN         NaN NaN  NaN  ...          3,50 -1,00 a 90°
# 154         NaN NaN         NaN NaN  NaN  ...         +1,50  -1,00  80º
# 236         NaN NaN         NaN NaN  NaN  ...         -1,75 -1,50 a 35°
# 13          NaN NaN         NaN NaN  NaN  ...        +0,50  -1,00  180º
# 14          NaN NaN         NaN NaN  NaN  ...         +0,75  -1,50 180º
# 264         NaN NaN         NaN NaN  NaN  ...        -6,00 -1,50 a 175°
# 246         NaN NaN         NaN NaN  NaN  ...          0,75 -1,00 a 90°
# 245         NaN NaN         NaN NaN  NaN  ...          0,75 -0,75 a 90°
# 21          NaN NaN         NaN NaN  NaN  ...           +0,50 -2,50 60º
# 22          NaN NaN         NaN NaN  NaN  ...   + 0,75    -3,00    105°
# 169         NaN NaN         NaN NaN  NaN  ...                    SEM RX
# 170         NaN NaN         NaN NaN  NaN  ...                    SEM RX
# 241         NaN NaN         NaN NaN  NaN  ...         2,00 -1,00 a 110°
# 242         NaN NaN         NaN NaN  NaN  ...          2,50 -1,00 a 50°
# 4           NaN NaN         NaN NaN  NaN  ...          +1,75  -1,75 70º
# 3           NaN NaN         NaN NaN  NaN  ...          +1,00 -2,00 100º
# 69          NaN NaN         NaN NaN  NaN  ...         +3,00  -0,50  35º
# 84          NaN NaN         NaN NaN  NaN  ...          plano -1,00  90º
# 83          NaN NaN         NaN NaN  NaN  ...          +1,00 -2,25  80º
# 252         NaN NaN         NaN NaN  NaN  ...          3,00 -1,25 a 90°
# 251         NaN NaN         NaN NaN  NaN  ...          2,75 -1,00 a 60°
# 119         NaN NaN         NaN NaN  NaN  ...         +0,75  -1,00  60º
# 237         NaN NaN         NaN NaN  NaN  ...         2,00 -1,25 a 180°
# 257         NaN NaN         NaN NaN  NaN  ...        4,75 - 1,25 a 100°
# 258         NaN NaN         NaN NaN  NaN  ...          5,25 -1,50 a 60°
# 263         NaN NaN         NaN NaN  NaN  ...         -0,50 -1,50 a 90°
# 262         NaN NaN         NaN NaN  NaN  ...         plano -1,50 a 65°
# 249         NaN NaN         NaN NaN  NaN  ...        -3,00 -1,00 a 165°
# 250         NaN NaN         NaN NaN  NaN  ...        -2,50 - 1,00 a 90°
# 243         NaN NaN         NaN NaN  NaN  ...        1,50 - 0,50 a 180°
# 244         NaN NaN         NaN NaN  NaN  ...       -1,50 - 0,50 a 180°
# 238         NaN NaN         NaN NaN  NaN  ...          2,75 -1,50 a 75°
# 239         NaN NaN         NaN NaN  NaN  ...         3,00 -1,25 a 105°
# 43          NaN NaN         NaN NaN  NaN  ...         +0,25  -1,00  75º
# 42          NaN NaN         NaN NaN  NaN  ...         +0,50  -1,00  85º
# 165         NaN NaN         NaN NaN  NaN  ...         -1,00  -2,00  60º
# 166         NaN NaN         NaN NaN  NaN  ...        -2,00  -2,00  100º
# 155         NaN NaN         NaN NaN  NaN  ...        +1,00  -1,75  105º
# 68          NaN NaN         NaN NaN  NaN  ...        +5,25  -1,00  150º
# 67          NaN NaN         NaN NaN  NaN  ...         +3,50  -0,50  85º
# 92          NaN NaN         NaN NaN  NaN  ...          +2,00  -0,75 55º
# 30          NaN NaN         NaN NaN  NaN  ...                sem rx pre
# 97          NaN NaN         NaN NaN  NaN  ...                sem rx pre
# 124         NaN NaN         NaN NaN  NaN  ...      +5,50    -5,25   60°
# 123         NaN NaN         NaN NaN  NaN  ...     +5,50    -3,50   110°
# 118         NaN NaN         NaN NaN  NaN  ...          +3,50 -0,75 180º
# 122         NaN NaN         NaN NaN  NaN  ...                    SEM RX
#
#     astig refracional pré op astig anterior topo pré op  \
# 98                     -2.00                        0.7
# 51                     -0.50                        0.4
# 240                    -3.00                        3.1
# 255                    -1.00                        1.4
# 256                    -1.50                        1.6
# 253                    -1.75                        1.9
# 254                    -1.25                        2.2
# 247                    -1.50                        0.5
# 248                    -1.25                        0.4
# 261                    -2.25                        0.7
# 260                    -1.00                        0.6
# 259                    -1.00                        0.7
# 154                    -1.00                        0.2
# 236                    -1.50                        2.9
# 13                     -1.00                        1.7
# 14                     -1.50                        2.2
# 264                    -1.50                        2.2
# 246                    -1.00                        0.5
# 245                    -0.75                        0.6
# 21                     -2.50                        0.7
# 22                     -3.00                        1.0
# 169                      NaN                        1.5
# 170                      NaN                        0.9
# 241                    -1.00                        0.5
# 242                    -1.00                        1.0
# 4                      -1.75                        1.0
# 3                      -2.00                        0.8
# 69                     -0.50                        1.2
# 84                     -1.00                        1.1
# 83                     -2.25                        1.4
# 252                    -1.25                        0.8
# 251                    -1.00                        0.9
# 119                    -1.00                        0.9
# 237                    -1.25                        2.1
# 257                    -1.25                        1.3
# 258                    -1.50                        1.6
# 263                    -1.50                        0.7
# 262                    -1.50                        1.2
# 249                    -1.00                        1.1
# 250                    -1.00                        0.4
# 243                    -0.50                        1.4
# 244                    -0.50                        1.7
# 238                    -1.50                        0.4
# 239                    -1.25                        0.7
# 43                     -1.00                        0.6
# 42                     -1.00                        0.9
# 165                    -2.00                        1.8
# 166                    -2.00                        0.5
# 155                    -1.75                        0.7
# 68                     -1.00                        0.6
# 67                     -0.50                        1.0
# 92                     -0.75                        0.8
# 30                       NaN                        0.3
# 97                       NaN                        0.9
# 124                    -5.25                        3.6
# 123                    -3.50                        3.4
# 118                    -0.75                        1.4
# 122                      NaN                        0.3
#
#      astig posterior topo pré     lente indicada   lente implantada   \
# 98                        0.1           T3 +9,00       T4 +11,0 a 5°
# 51                        0.1                NaN      T3 23,5 a 170°
# 240                       0.8   T5 +17,0  a 104°  T6 + 17,0 D à 100°
# 255                       0.5   T2 +14,50 a 110°           T3 a 100°
# 256                       0.4     T2 +13,0 a 79°            T4 a 85°
# 253                       0.4    T4 +14,0 a 104°     T4 +14,0 a 100°
# 254                       0.3   T4 +13,50  a 95°      T4 +13,5 a 95°
# 247                       0.1     T3 +22,50 a 7°       T3 +23,0 a 5°
# 248                       0.2     T3 +23,50 a 1°     T3 +23,5 a 180°
# 261                       0.1    T4 +21,0 a 180°     T4 +21,5 a 170°
# 260                       0.1    T2 +23,0 a 175°      T3 +23,0 a 15°
# 259                       0.1     T2 +23,0 a 10°      T3 +23,0 a 18°
# 154                       0.3          T2 +21,00     T3 +21,0 à 167°
# 236                       0.7    T7 +13,0 a 112°                 NaN
# 13                        0.4                NaN      T3 +20,0 a 85°
# 14                        0.4                NaN      T4 +20,0 a 90°
# 264                       0.4     T3 +12,0 a 58°        14,00 a 157°
# 246                       0.2     T3 +20,0  a 1°            T3 +20,5
# 245                       0.2    T4 +20,50  a 2°           T4  +21,0
# 21                        0.2          T4 +18,50    T4  +19,0 a 165°
# 22                        0.1          T4  +19.0     T6  +19,5 a 12°
# 169                       0.1        T2   +24,00      T3 +23, a 180°
# 170                       0.2        T2   +23,00    T4  +23,0 a 150°
# 241                       0.2   T2 +20,50  a 20°     T3  +20,5 a 25°
# 242                       0.3   T3 +21,0  a 172°    T3  +21,0 a 165°
# 4                         0.0                NaN     T5 +22,0 a 180°
# 3                         0.1                NaN    T5 +22,50 a 160°
# 69                        0.2                NaN   T2 +22.5 D à 120°
# 84                        0.1                NaN    T4 +17.5 D à 13°
# 83                        0.1                NaN          T5 +18,5D
# 252                       0.1     T4 +23,50 a 3°     T4 +24,5 a 180°
# 251                       0.1   T4 +22,50  a  4°       T3 +23,0 a 5°
# 119                       0.4         T2  +23,00      T3 +23,0 a 35°
# 237                       0.5     T3 +24,0 a 85°      T3 +24,5 a 85°
# 257                       0.1    T2 +26,0  a 29°            T3 +26,5
# 258                       0.2    T3 +27,0 a 147°   T4  +27,0  a 145°
# 263                       0.1     T4 +22,50 a 6°    T4 +23,5 D à 10°
# 262                       0.1  T4 +22,50  a 173°   T4 +22,5 D à 170°
# 249                       0.1   T3 +19,50  a 13°    T3 +20,0 D à 20°
# 250                       0.0    T2 +20,0  a 12°    T3 +21,0 D à 30°
# 243                       0.5    T2 +22,50 a 90°     T2 + 23,0 a 90°
# 244                       0.5    T2 +22,0  a 87°     T2 + 23,0 a 85°
# 238                       0.3   T2 +21,50 a 177°     T3 +23,5 a 175°
# 239                       0.2    T3 +22,50 a 16°        T3 +22,5 20°
# 43                        0.2                NaN    T3 +21,50 a 170°
# 42                        0.2                NaN    T3 +21,0D a 180°
# 165                       0.6                NaN   T5 +18,5 D à 140°
# 166                       0.5          T6 +17,50    T5 +17,5 D à 30°
# 155                       0.0         T3  +21,00      T4 +21,5 a 20°
# 68                        0.2                NaN    T4 +24,5 D à 62°
# 67                        0.1                NaN     T3 +25.5 D à 2°
# 92                        0.2          T3 +21,00   T2 +20,50D a 112°
# 30                        0.3                NaN     T2 +23,0 a 170°
# 97                        0.2                NaN   T3 +29,5 D à 160°
# 124                       0.6          T8 +27,00     T9 +29,0 a 153°
# 123                       0.5         T7  +26,50      T8 +27,0 a 45°
# 118                       0.5         T4  +22,00    T3 +21,5D à 33°
# 122                       0.2         T2  +20,00    T9  +18,5 a 151°
#
#     refração pós operatória astig refracional pós op   \
# 98        +0,25  -1,50  30º                     -1.50
# 51                    plano                      0.00
# 240                    0.25                      0.00
# 255     -0,50 - 0,25 a 175°                     -0.25
# 256                   plano                      0.00
# 253                   plano                      0.00
# 254                   plano                      0.00
# 247                     NaN                       NaN
# 248                     NaN                       NaN
# 261                    -0.5                      0.00
# 260                     NaN                       NaN
# 259                     NaN                       NaN
# 154                   plano                      0.00
# 236      plano -0,75 a 110°                     -0.75
# 13          plano -0,50 60º                     -0.50
# 14          plano -0,50 60º                     -0.50
# 264       -0,75 -0,50 a 10°                     -0.50
# 246       plano -0,50 a 10°                     -0.50
# 245      -0,25 -0,50 a 170°                     -0.50
# 21        -0,25  -0,50  90º                     -0.50
# 22        -0,50  -0,50  30º                     -0.50
# 169                  SEM RX                       NaN
# 170                  SEM RX                       NaN
# 241                   plano                      0.00
# 242     plano - 0,50 a 115°                     -0.50
# 4                     plano                      0.00
# 3         plano -0,75  150º                     -0.75
# 69                     0.25                      0.00
# 84                    plano                      0.00
# 83                    plano                      0.00
# 252     -0,25 - 0,50 a 170°                     -0.50
# 251                   plano                      0.00
# 119      +0,25  -0,50  160º                     -0.50
# 237        0,50 -0,25 a 15°                     -0.25
# 257                     NaN                       NaN
# 258                     NaN                       NaN
# 263                   -0.25                      0.00
# 262                   plano                      0.00
# 249                   plano                      0.00
# 250                   plano                      0.00
# 243                     NaN                       NaN
# 244                     NaN                       NaN
# 238                    -1.5                      0.00
# 239                   -0.25                      0.00
# 43                    plano                      0.00
# 42                    plano                      0.00
# 165        plano -0,50  90º                     -0.50
# 166                   plano                      0.00
# 155                   plano                      0.00
# 68        -0,25  -0,50  80º                     -0.50
# 67                       -1                      0.00
# 92                    plano                      0.00
# 30                    plano                      0.00
# 97         plano -0,50  95º                     -0.50
# 124                    -0.5                      0.00
# 123                   PLANO                      0.00
# 118        +0,25 -0,50 180º                     -0.50
# 122                  SEM RX                       NaN
#
#                classificação astigmatismo   tem_exame
# 98                                     NaN      False
# 51               Regular simétrico obliquo      False
# 240                                    NaN      False
# 255                                    NaN      False
# 256                                    NaN      False
# 253                                    NaN      False
# 254                                    NaN      False
# 247                                    NaN      False
# 248                                    NaN      False
# 261                                    NaN      False
# 260                                    NaN      False
# 259                                    NaN      False
# 154                                    NaN      False
# 236                                    NaN      False
# 13      Regular simétrico a favor da regra      False
# 14   Regular assimetrico a favor da regra       False
# 264                                    NaN      False
# 246                                    NaN      False
# 245                                    NaN      False
# 21              Regular simétrico obliquo       False
# 22        Regular simetrico contra a regra      False
# 169                                    NaN      False
# 170                                    NaN      False
# 241                                    NaN      False
# 242                                    NaN      False
# 4        Regular simetrico contra a regra       False
# 3       Regular assimétrico contra a regra      False
# 69               Regular simétrico obliquo      False
# 84        Regular simétrico contra a regra      False
# 83       Regular simetrico contra a regra       False
# 252                                    NaN      False
# 251                                    NaN      False
# 119             Regular simétrico oblíquo       False
# 237                                    NaN      False
# 257                                    NaN      False
# 258                                    NaN      False
# 263                                    NaN      False
# 262                                    NaN      False
# 249                                    NaN      False
# 250                                    NaN      False
# 243                                    NaN      False
# 244                                    NaN      False
# 238                                    NaN      False
# 239                                    NaN      False
# 43        Regular simétrico contra a regra      False
# 42        Regular simétrico contra a regra      False
# 165                                    NaN      False
# 166                                    NaN      False
# 155                                    NaN      False
# 68             Regular assimétrico obliquo      False
# 67        Regular simétrico contra a regra      False
# 92    Regular assimétrico a favor da regra      False
# 30      Regular simétrico a favor da regra      False
# 97             Regular assimétrico oblíquo      False
# 124             Regular simétrico oblíquo       False
# 123             Regular simétrico oblíquo       False
# 118              Regular simétrico obliquo      False
# 122   Regular assimétrico a favor da regra      False
#
# [58 rows x 22 columns]
